# %% [markdown]
# <center><h1>THU THẬP DỮ LIỆU LAPTOP<br> ĐỂ PHÂN LOẠI VÀ DỰ ĐOÁN SẢN PHẨM PHÙ HỢP<br> VỚI MỘT NHU CẦU CHO TRƯỚC</h1></center>
#
# <h3>Nhóm:</h3>
# <ul>
#     <li>1612001: Hoàng Dân An</li>
#     <li>1612065: Nguyễn Đào Vinh Hải</li>
# </ul>

# %% [markdown]
# ## NGUỒN THU THẬP
# Thông tin laptop và đánh giá sẽ được thu thập trên các trang thương mại điện tử như:
# ### 1. TIKI
# ### 2. Điện máy xanh
# ### 3. Thegioididong
# ### 4. Nguyễn Kim
# ### 5. FPT
# ### 6. Phong vũ

# %% [markdown]
# ## THÔNG TIN THU THẬP
# 1. Bao gồm Thông tin chi tiết về laptop (RAM, Size, Weight, ...) **(1204 records - Tiki)**
# 2. Comments/Đánh giá của người mua **(0-10 đánh giá mỗi sản phẩm)**

# %%
import pandas as pd
df = pd.read_csv("tiki_detail.csv")
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
# 5           5             5
# 6           6             6
# 7           7             7
# 8           8             8
# 9           9             9
#
#                                                title   brand     price  \
# 0  Laptop Asus Vivobook S15 S530UA-BQ034T Core i3...    Asus  10769000
# 1  Asus F570ZD FY415T AMD R5-2500U/ VGA GTX1050/ ...    Asus  16170000
# 2  Laptop Asus ASUSPRO B9440UA-GV0495T Core i5-82...    Asus  19499000
# 3  Dell Inspiron 3480-N4I5107W: i5-8265U | 4GB RA...    Dell  12890000
# 4  Apple Macbook Air 2019 - 13 inchs (i5/ 8GB/ 12...   Apple  25490000
# 5  Laptop Asus Vivobook 14 A412FA-EK224T Core i5-...    Asus  15399000
# 6  Laptop Lenovo Ideapad 130-15AST 81H5000VVN AMD...  Lenovo   5549000
# 7  Macbook Air 2017 MQD32 (13.3 inch) - Hàng Chín...   Apple  20709000
# ...

# %% [markdown]
# ## INPUT - OUTPUT
#
# Cho một tên nhu cầu cố định:
# - Văn phòng
# - Game
# - Học tập
# - ...
#
# và một số thông tin có thêm được từ người dùng (**optional**)
# - Ngành học
# - Công việc
# - Mức giá / Thu nhập
#
# và 1 thuật toán / giả định:
# - Về giới tính
# - Xu hướng sử dụng
# - ...
#
# <center><h2>Đề xuất một danh sách laptop tốt nhất với nhu cầu người mua?</h2></center>
#
# <img src='../image/PredictDiagram.png' />

# %% [markdown]
# ## LỢI ÍCH TỪ CÂU TRẢ LỜI
#
# ### - Cải thiện chất lượng hệ thống **Tìm kiếm** của một trang bán hàng
# ### - Tăng hiệu suất quảng cáo
